# %%
# Import Dependencies
import pandas as pd
import datetime
import time

# %%
df1 = pd.read_csv("../FluViewPhase2Data/ILINet.csv")
df1.head(500)
# Out:
#     REGION TYPE                REGION  YEAR  WEEK %WEIGHTEDILI  \
# 0        States               Alabama  2010    40            X
# 1        States                Alaska  2010    40            X
# 2        States               Arizona  2010    40            X
# 3        States              Arkansas  2010    40            X
# 4        States            California  2010    40            X
# 5        States              Colorado  2010    40            X
# 6        States           Connecticut  2010    40            X
# 7        States              Delaware  2010    40            X
# 8        States  District of Columbia  2010    40            X
# 9        States               Florida  2010    40            X
# 10       States               Georgia  2010    40            X
# 11       States                Hawaii  2010    40            X
# 12       States                 Idaho  2010    40            X
# 13       States              Illinois  2010    40            X
# ...

# %%
# Create Loop:
#  1.) Go through each row and if the value in Region is unique create a new list and grab its corresponding "%UNWEIGHTED ILI" value.
#  2.) As loop is going if it comes across a similar Region then add the corresponding "%UNWEIGHTED ILI" value to corresponding list.

# selecting rows based on condition 
options = ['40']

rslt_df = df1.loc[(df1['REGION'] == "Alabama") & 
              df1['WEEK'].isin(options)] 
  
rslt_df["%UNWEIGHTED ILI"].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1163         try:
# -> 1164             x = float(x)
#    1165         except Exception:
#
# ValueError: could not convert string to float: '2.134772.494861.494041.590441.731742.588752.223981.757211.62738'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1166             try:
# -> 1167                 x = complex(x)
#    1168             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ...
