# %%
# %matplotlib inline
    
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
# final df for model building
df1 = pd.read_csv("ILI_weeks by test scores with respective ML models.csv")
df1.head(2)
# Out:
#    Unnamed: 0  \
# 0         NaN
# 1         NaN
#
#   Summary Table I. r2_score(R2),  Mean Squared Error(MSE), Mean Absolute Error(MAE) by Machine learning models  \
# 0                                             Model
# 1                                                NaN
#
#    Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7  \
# 0         NaN  ILI_lagwk1        NaN        NaN        NaN  ILI_lagwk2
# 1         NaN         R2         NaN        MSE        MAE         R2
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0        NaN        NaN         NaN  ILI_lagwk3         NaN         NaN
# 1        NaN        MSE         MAE         R2          NaN         MSE
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18
# 0         NaN  ILI_lagwk4         NaN         NaN         NaN
# 1         MAE         R2          NaN         MSE         MAE

# %%
df1.transpose()
# Out:
#                                                              0    1      2  \
# Unnamed: 0                                                 NaN  NaN    NaN
# Summary Table I. r2_score(R2),  Mean Squared Er...      Model   NaN    NaN
# Unnamed: 2                                                 NaN  NaN    NaN
# Unnamed: 3                                          ILI_lagwk1  R2   Train
# Unnamed: 4                                                 NaN  NaN   Test
# Unnamed: 5                                                 NaN  MSE    NaN
# Unnamed: 6                                                 NaN  MAE    NaN
# Unnamed: 7                                          ILI_lagwk2  R2   Train
# Unnamed: 8                                                 NaN  NaN   Test
# Unnamed: 9                                                 NaN  MSE    NaN
# Unnamed: 10                                                NaN  MAE    NaN
# ...
