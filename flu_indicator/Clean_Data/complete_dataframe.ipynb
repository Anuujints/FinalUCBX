# %%
# Import Dependencies
import pandas as pd

# %%
df = pd.read_csv("../../ih_flu/Google_Trends_concat.csv")
df.head()
# Out:
#   Year_week  a_influenza  acute_bronchitis  body_temperature  \
# 0    2004_1           11                50                58
# 1    2004_2            7                41                70
# 2    2004_3            6                40                53
# 3    2004_4            4                32                57
# 4    2004_5            3                31                46
#
#    braun_thermoscan  break_a_fever  bronchitis  chest_cold  cold_and_flu  \
# 0               100             15          34          27            26
# 1                54             12          31          17            20
# 2                40             15          29          20            16
# 3                26             18          25          21            12
# 4                80             21          25           9            10
#
#    cold_or_flu  ...  treating_the_flu  treatment_for_flu  \
# 0           39  ...                78                  7
# 1           11  ...                41                  9
# 2            8  ...                41                  6
# 3           13  ...                41                  5
# 4           15  ...                42                  5
#
#    treatment_for_the_flu  tussin  tussionex  type_a_influenza  \
# 0                     42      64         79                20
# 1                      0      20         58                16
# 2                      0      44         52                16
# 3                      0      52         42                16
# 4                      0      34         51                18
#
#    upper_respiratory  walking_pneumonia  what_to_do_if_you_have_the_flu  \
# 0                 37                 57                               0
# 1                 21                 42                               0
# 2                 17                 38                               0
# 3                 24                 45                               0
# 4                 25                 26                               0
#
#    ILI_Total
# 0       7602
# 1       5583
# 2       4961
# 3       4436
# 4       4251
#
# [5 rows x 131 columns]

# %%
df = df.drop('Year_week', axis=1)

# %%
X = df.drop('ILI_Total', axis=1)
y = df[['ILI_Total']]

from sklearn.model_selection import train_test_split

# Split X and y into X_
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for a_influenza is 78.84691070023487
# The coefficient for acute_bronchitis is 13.379947538363439
# The coefficient for body_temperature is -24.448477342189243
# The coefficient for braun_thermoscan is 19.644741577396918
# The coefficient for break_a_fever is -0.05344175261597783
# The coefficient for bronchitis is -89.08542698746194
# The coefficient for chest_cold is 35.79377755847925
# The coefficient for cold_and_flu is 729.571896403363
# The coefficient for cold_or_flu is -1261.5819388746318
# The coefficient for cold_versus_flu is -205.23727513889293
# The coefficient for cold_vs_flu is -0.8648801022075858
# The coefficient for contagious_flu is 678.7458796759976
# The coefficient for cough_fever is 969.083178878356
# The coefficient for cure_flu is -131.0321961765201
# The coefficient for cure_the_flu is 28.471935257817606
# The coefficient for dangerous_fever is -10.848302789351905
# The coefficient for do_i_have_the_flu is 69.18321248049939
# The coefficient for ear_thermometer is -24.610541139353863
# The coefficient for early_flu_symptoms is -64.71480924432481
# The coefficient for expectorant is 6.913699266852262
# The coefficient for exposed_to_flu is 58.67956653393841
# The coefficient for fever_cough is -820.2336653768797
# The coefficient for fever_flu is 66.24925038227754
# The coefficient for fever_reducer is -21.520783670702272
# The coefficient for fight_the_flu is -24.75931078920926
# The coefficient for flu_and_cold is -738.9882008928581
# The coefficient for flu_and_fever is 5.263504739380792
# The coefficient for flu_care is -81.9491575599383
# The coefficient for flu_children is 497.0735537229806
# The coefficient for flu_complications is -55.46668892352652
# The coefficient for flu_contagious_period is -14.113250303560676
# The coefficient for flu_contagious is -690.1437708002861
# The coefficient for flu_cough is 0.29263658908305956
# The coefficient for flu_duration is -12.690633276709079
# The coefficient for flu_fever is 66.24925038225763
# The coefficient for flu_germs is -46.907582962380026
# The coefficient for flu_headache is -67.48851768321413
# The coefficient for flu_how_long is -48.316965566684104
# The coefficient for flu_in_children is 60.83215161679625
# The coefficient for flu_incubation_period is -277.2594074086869
# The coefficient for flu_incubation is -203.59422907853263
# The coefficient for flu_lasts is -30.21929259609749
# The coefficient for flu_length is -25.836591083202308
# The coefficient for flu_medicine is -22.43288462917544
# The coefficient for flu_or_cold is 1278.6904161704451
# The coefficient for flu_recovery is -18.515657539441015
# The coefficient for flu_relief is -31.599134304644508
# The coefficient for flu_remedies is -56.61938222209133
# The coefficient for flu_remedy is 10.068753957253726
# The coefficient for flu_report is 133.21142989289854
# The coefficient for flu_reports is -102.8047192656904
# The coefficient for flu_symptoms is -460.26968824626715
# The coefficient for flu_test is 227.86389699724415
# The coefficient for flu_treatment is 95.85468258648784
# The coefficient for flu_treatments is -13.823118203080142
# The coefficient for flu_versus_cold is 206.94031680955226
# The coefficient for flu_vs_cold is -0.8648801022093409
# The coefficient for get_over_the_flu is 16.68413316656369
# The coefficient for get_rid_of_the_flu is 93.95131073824209
# The coefficient for having_the_flu is -28.722768201800736
# The coefficient for high_fever is 13.965825094126295
# The coefficient for how_long_contagious is -46.49489885540572
# The coefficient for how_long_does_flu_last is -117.99322223679962
# The coefficient for how_long_does_the_flu_last is -14.525040674541685
# The coefficient for how_long_flu is -48.316965566687145
# The coefficient for how_long_is_flu_contagious is -296.2311151653606
# The coefficient for how_long_is_the_flu_contagious is 100.14847987445074
# The coefficient for how_long_is_the_flu is 243.00514648685265
# The coefficient for how_to_get_rid_of_the_flu is -72.7020924126815
# The coefficient for how_to_treat_flu is 103.4297944970642
# The coefficient for how_to_treat_the_flu is 22.04022240828857
# The coefficient for human_temperature is 5.5642709350939015
# The coefficient for i_have_the_flu is 25.503944910036722
# The coefficient for incubation_period_for_flu is -46.07007208634693
# The coefficient for incubation_period_for_the_flu is -13.155793416176806
# The coefficient for influenza_a_and_b is -20.69019179847939
# The coefficient for influenza_a is 78.84691070019124
# The coefficient for influenza_contagious is 3.843523978429289
# The coefficient for influenza_incubation_period is -28.27629801731854
# The coefficient for influenza_incubation is 41.253224370377396
# The coefficient for influenza_symptoms is -42.04045688045875
# The coefficient for influenza_treatment is 8.64492295227717
# The coefficient for influenza_type_a is 38.03463286807943
# The coefficient for is_flu_contagious is 103.95649051035838
# The coefficient for low_body is 9.75926179428176
# The coefficient for medicine_for_flu is -29.154700230278944
# The coefficient for medicine_for_the_flu is 18.813758462161292
# The coefficient for normal_body_temperature is -28.387924908080947
# The coefficient for normal_body is 22.854805314633666
# The coefficient for oscillococcinum is 94.14957656642036
# The coefficient for over_the_counter_flu_medicine is 15.69799039337429
# The coefficient for over_the_counter_flu is 99.44219434305418
# The coefficient for painful_cough is -4.252365780277003
# The coefficient for pneumonia is 67.39914392479747
# The coefficient for rapid_flu is 27.48638209418705
# The coefficient for reduce_a_fever is 2.1201684148696813
# The coefficient for reduce_fever is 58.85935602548609
# The coefficient for remedies_for_flu is 23.507976735999616
# The coefficient for remedies_for_the_flu is -4.556804087629871
# The coefficient for respiratory_flu is 59.21822923819766
# The coefficient for robitussin is 32.21607892884299
# The coefficient for signs_of_flu is 604.8697691272424
# The coefficient for signs_of_the_flu is -240.19309446098578
# The coefficient for sinus_infections is 28.125771134971046
# The coefficient for sinus is -21.70221800749512
# The coefficient for strep_throat is -5.834191736515422
# The coefficient for strep is 66.1887720407734
# The coefficient for symptoms_of_bronchitis is 47.65544167962712
# The coefficient for symptoms_of_flu is 441.65366666921943
# The coefficient for symptoms_of_influenza is -53.967540916044044
# The coefficient for symptoms_of_pneumonia is 29.055767097358306
# The coefficient for symptoms_of_the_flu is 41.38051593240229
# The coefficient for taking_temperature is 28.245188427781144
# The coefficient for tessalon is -8.091741879963564
# The coefficient for the_flu_virus is 25.77775384028979
# The coefficient for the_flu is -493.60811336761145
# The coefficient for thermoscan is -1.645514662575124
# The coefficient for treat_flu is -1.5193099589348122
# The coefficient for treat_the_flu is -10.77148063689387
# The coefficient for treating_flu is -20.241441578680888
# The coefficient for treating_the_flu is 31.463249768746252
# The coefficient for treatment_for_flu is -130.84805877625638
# The coefficient for treatment_for_the_flu is 2.4973157273746374
# The coefficient for tussin is 16.776795902067306
# The coefficient for tussionex is 60.886400246969316
# The coefficient for type_a_influenza is 38.03463286807863
# The coefficient for upper_respiratory is -35.95180711699244
# The coefficient for walking_pneumonia is -21.50302651902453
# The coefficient for what_to_do_if_you_have_the_flu is 11.19573348329508

# %%
intercept = regression_model.intercept_[0]

print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is -7281.213593135642

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.8813693040204451

# %%
from sklearn.metrics import mean_squared_error

y_predict = regression_model.predict(X_test)

regression_model_mse = mean_squared_error(y_predict, y_test)

regression_model_mse
# Out:
# 6701213.988120561

# %%
import math

math.sqrt(regression_model_mse)
# Out:
# 2588.670312751425
