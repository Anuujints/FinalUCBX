# %%
# Import Dependencies
import pandas as pd
import datetime
import time

# %%
df1 = pd.read_csv("../Clean_Data/ILI_Weekly_State_Avg.csv")
df1.head(10)
# Out:
#                  REGION    week_1    week_2    week_3    week_4    week_5  \
# 0               Alabama  6.370629  6.964126  7.661381  7.435979  7.277602
# 1                Alaska  1.766894  2.010301  1.993347  1.771273  2.355049
# 2               Arizona  2.901751  2.649474  3.168582  3.214370  3.087903
# 3              Arkansas  4.281816  5.101146  5.373053  5.374030  5.660437
# 4            California  4.028955  3.694313  3.826214  4.235409  4.227718
# 5              Colorado  2.049578  1.889047  2.030161  2.077329  2.236662
# 6           Connecticut  2.400804  2.642843  3.068027  3.096562  3.470586
# 7              Delaware  1.338100  1.960417  1.922858  2.073742  1.787819
# 8  District of Columbia  8.171689  7.175295  5.408062  6.251099  6.358745
# 9               Florida  0.000000  0.000000  0.000000  0.000000  0.000000
#
#      week_6    week_7    week_8    week_9  ...   week_44   week_45   week_46  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1163         try:
# -> 1164             x = float(x)
#    1165         except Exception:
#
# ValueError: could not convert string to float: '2.134772.494861.494041.590441.731742.588752.223981.757211.62738'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1166             try:
# -> 1167                 x = complex(x)
#    1168             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ...
