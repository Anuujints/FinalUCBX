# %%
# %matplotlib inline

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor

import seaborn as sns
np.random.seed(0)

# %%
df1 = pd.read_csv("Google_Trends_combined_allyears.csv")
df1.dropna(how='any', inplace=True)
# del df1['week']
# del df1['Unnamed: 0']

# del df1['Week']

df1.head()
# Out:
#      Year  week ILI_weeks  a_influenza  acute_bronchitis  body_temperature  \
# 285  2009    27     WK_27           36                20                43
# 286  2009    28     WK_28           25                19                40
# 287  2009    29     WK_29           24                30                45
# 288  2009    30     WK_30           23                19                40
# 289  2009    31     WK_31           27                21                44
#
#      braun_thermoscan  break_a_fever  bronchitis  chest_cold     ...      \
# 285                27             11          22          16     ...
# 286                31             10          21          11     ...
# 287                20             12          20          20     ...
# 288                15             10          19          12     ...
# 289                20             11          19          17     ...
#
#      walking_pneumonia  what_to_do_if_you_have_the_flu  Flu_Visit_Count  \
# ...

# %%
df1.to_csv("droppedNan_Google_Trends_combined_allyears.csv")
df1.head()
# Out:
#      Year  week ILI_weeks  a_influenza  acute_bronchitis  body_temperature  \
# 285  2009    27     WK_27           36                20                43
# 286  2009    28     WK_28           25                19                40
# 287  2009    29     WK_29           24                30                45
# 288  2009    30     WK_30           23                19                40
# 289  2009    31     WK_31           27                21                44
#
#      braun_thermoscan  break_a_fever  bronchitis  chest_cold     ...      \
# 285                27             11          22          16     ...
# 286                31             10          21          11     ...
# 287                20             12          20          20     ...
# 288                15             10          19          12     ...
# 289                20             11          19          17     ...
#
#      walking_pneumonia  what_to_do_if_you_have_the_flu  Flu_Visit_Count  \
# ...

# %%
df2 = pd.read_csv("Google_Trends_combined_allyears.csv")
# df2.dropna(how='any', inplace=True)
# del df1['week']
# del df1['Unnamed: 0']

# del df1['Week']

df2.head()
# Out:
#    Year  week ILI_weeks  a_influenza  acute_bronchitis  body_temperature  \
# 0  2004     1      WK_1           11                50                58
# 1  2004     2      WK_2            7                41                70
# 2  2004     3      WK_3            6                40                53
# 3  2004     4      WK_4            4                32                57
# 4  2004     5      WK_5            3                31                46
#
#    braun_thermoscan  break_a_fever  bronchitis  chest_cold     ...      \
# 0               100             15          34          27     ...
# 1                54             12          31          17     ...
# 2                40             15          29          20     ...
# 3                26             18          25          21     ...
# 4                80             21          25           9     ...
#
#    walking_pneumonia  what_to_do_if_you_have_the_flu  Flu_Visit_Count  \
# ...

# %%
# new_df = df1['Year_week'].str.split('_')
# new_df.head(3)

# %%
# df = df1['Year_week'].str.split('_', expand=True)
# df.head(3)

# %%
# # 3) add new column to old dataframe
# df1[['year','wk']] = df1['Year_week'].str.split('_', expand=True)
# df1.dropna(how='any', inplace=True)
# del df1['wk']
# del df1['Year_week']

# df1.head()

# %%
# df1 = df1.set_index(["year"])
# df1.head()
