# %%
from numpy.random import seed
seed(1)

# %%
import numpy as np
import pandas as pd

# %%
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.2.4-tf'

# %%
g_trend = pd.read_csv("Google_Trends_concat.csv")
g_trend.head()
# Out:
#   Year_week  a_influenza  acute_bronchitis  body_temperature  \
# 0    2004_1           11                50                58
# 1    2004_2            7                41                70
# 2    2004_3            6                40                53
# 3    2004_4            4                32                57
# 4    2004_5            3                31                46
#
#    braun_thermoscan  break_a_fever  bronchitis  chest_cold  cold_and_flu  \
# 0               100             15          34          27            26
# 1                54             12          31          17            20
# 2                40             15          29          20            16
# 3                26             18          25          21            12
# 4                80             21          25           9            10
#
#    cold_or_flu  ...  treating_the_flu  treatment_for_flu  \
# 0           39  ...                78                  7
# 1           11  ...                41                  9
# 2            8  ...                41                  6
# 3           13  ...                41                  5
# 4           15  ...                42                  5
#
#    treatment_for_the_flu  tussin  tussionex  type_a_influenza  \
# 0                     42      64         79                20
# 1                      0      20         58                16
# 2                      0      44         52                16
# 3                      0      52         42                16
# 4                      0      34         51                18
#
#    upper_respiratory  walking_pneumonia  what_to_do_if_you_have_the_flu  \
# 0                 37                 57                               0
# 1                 21                 42                               0
# 2                 17                 38                               0
# 3                 24                 45                               0
# 4                 25                 26                               0
#
#    ILI_Total
# 0       7602
# 1       5583
# 2       4961
# 3       4436
# 4       4251
#
# [5 rows x 131 columns]

# %%
features = g_trend.drop("ILI_Total", axis=1).values
labels= g_trend["ILI_Total"].values
X = features[:, 0:649]
y = labels[:, 649]
print(X.shape, y.shape)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-83a22c909618> in <module>
#       2 labels= g_trend["ILI_Total"].values
#       3 X = features[:, 0:649]
# ----> 4 y = labels[:, 649]
#       5 print(X.shape, y.shape)
#
# IndexError: too many indices for array

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.33)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-492c50fd1e3b> in <module>
#      13 label_encoder.fit(y_train)
#      14 encoded_y_train = label_encoder.transform(y_train)
# ---> 15 encoded_y_test = label_encoder.transform(y_test)
#      16
#      17 # Step 2: Convert encoded labels to one-hot-encoding
#
# c:\users\ihuang\appdata\local\continuum\anaconda3\envs\neuralnetwork\lib\site-packages\sklearn\preprocessing\label.py in transform(self, y)
#     255             return np.array([])
#     256
# --> 257         _, y = _encode(y, uniques=self.classes_, encode=True)
#     258         return y
#     259
#
# c:\users\ihuang\appdata\local\continuum\anaconda3\envs\neuralnetwork\lib\site-packages\sklearn\preprocessing\label.py in _encode(values, uniques, encode)
#     108         return res
#     109     else:
# --> 110         return _encode_numpy(values, uniques, encode)
#     111
#     112
#
# c:\users\ihuang\appdata\local\continuum\anaconda3\envs\neuralnetwork\lib\site-packages\sklearn\preprocessing\label.py in _encode_numpy(values, uniques, encode)
#      47         if diff:
#      48             raise ValueError("y contains previously unseen labels: %s"
# ---> 49                              % str(diff))
#      50         encoded = np.searchsorted(uniques, values)
#      51         return uniques, encoded
#
# ValueError: y contains previously unseen labels: [719, 809, 851, 960, 990, 1023, 1033, 1037, 1116, 1169, 1172, 1219, 1283, 1331, 1359, 1373, 1394, 1456, 1457, 1645, 1705, 2166, 2300, 2429, 2461, 2708, 2780, 2860, 2990, 3012, 3077, 3171, 3177, 3400, 3538, 3550, 3586, 3631, 3824, 3825, 3850, 3874, 3950, 4019, 4122, 4168, 4186, 4218, 4224, 4251, 4436, 4444, 4445, 4506, 4510, 4691, 4798, 4953, 4971, 5007, 5026, 5038, 5051, 5053, 5083, 5103, 5291, 5316, 5352, 5380, 5407, 5409, 5455, 5510, 5526, 5547, 5738, 5755, 5786, 5896, 5959, 5964, 6048, 6133, 6139, 6281, 6290, 6362, 6387, 6444, 6530, 6589, 6668, 7110, 7222, 7227, 7229, 7307, 7348, 7434, 7602, 7878, 7900, 7914, 7986, 8200, 8339, 8473, 8527, 8570, 8576, 8577, 8695, 8708, 8797, 8956, 8999, 9033, 9289, 9347, 9391, 9502, 9551, 9597, 9677, 9684, 9706, 10158, 10732, 10814, 11020, 11021, 11061, 11149, 11187, 11297, 11343, 11456, 11496, 11601, 11721, 11743, 11807, 11930, 11939, 12036, 12120, 12123, 12126, 12311, 12502, 12554, 12635, 12957, 13040, 13234, 13498, 13714, 13997, 14048, 14088, 14102, 14197, 14324, 14448, 14524, 14661, 14769, 14958, 15122, 15635, 15711, 15914, 16087, 16518, 16594, 16967, 17150, 17309, 17911, 18022, 19231, 19325, 19398, 19505, 19512, 19899, 20519, 20721, 21469, 21730, 22321, 22508, 24697, 24721, 26257, 28147, 28370, 28654, 29432, 29627, 30245, 30943, 31277, 32520, 34103, 34332]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(units=64, activation='relu', input_dim=20))
